# %%
import sys
import os

# Add the project root directory to sys.path
project_root = os.path.abspath(os.path.join(os.getcwd(), "../.."))  # Adjust to your project's structure
sys.path.append(project_root)

from src.analysis import *
import plotly.graph_objects as go

# %%
player_df, team_df, mvp_df = load_year(2023)
plot_2023 = per_ws_vs_mvp_points(player_df, team_df, mvp_df)

player_df, team_df, mvp_df = load_year(2022)
plot_2022 = per_ws_vs_mvp_points(player_df, team_df, mvp_df)

# %%
print(plot_2023)
print(plot_2022)
# Out:
# Figure({
#     'data': [{'hovertemplate': ('<b>%{hovertext}</b><br><br>TEA' ... '=%{marker.size}<extra></extra>'),
#               'hovertext': array(['GIANNIS ANTETOKOUNMPO'], dtype=object),
#               'legendgroup': 'MIL',
#               'marker': {'color': '#636efa',
#                          'opacity': 0.8,
#                          'size': array([2222]),
#                          'sizemode': 'area',
#                          'sizeref': 5.925,
#                          'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'MIL',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([16.91266069]),
#               'xaxis': 'x',
#               'y': array([192]),
#               'yaxis': 'y'},
#              {'hovertemplate': ('<b>%{hovertext}</b><br><br>TEA' ... '=%{marker.size}<extra></extra>'),
#               'hovertext': array(['JALEN BRUNSON'], dtype=object),
#               'legendgroup': 'NYK',
#               'marker': {'color': '#EF553B',
#                          'opacity': 0.8,
#                          'size': array([2212]),
#                          'sizemode': 'area',
#                          'sizeref': 5.925,
#                          'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'NYK',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([11.59853265]),
#               'xaxis': 'x',
#               'y': array([142]),
#               'yaxis': 'y'},
#              {'hovertemplate': ('<b>%{hovertext}</b><br><br>TEA' ... '=%{marker.size}<extra></extra>'),
#               'hovertext': array(['LUKA DONČIĆ'], dtype=object),
#               'legendgroup': 'DAL',
#               'marker': {'color': '#00cc96',
#                          'opacity': 0.8,
#                          'size': array([2370]),
#                          'sizemode': 'area',
#                          'sizeref': 5.925,
#                          'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'DAL',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([15.64481707]),
#               'xaxis': 'x',
#               'y': array([566]),
#               'yaxis': 'y'},
#              {'hovertemplate': ('<b>%{hovertext}</b><br><br>TEA' ... '=%{marker.size}<extra></extra>'),
#               'hovertext': array(['KEVIN DURANT'], dtype=object),
#               'legendgroup': 'PHX',
#               'marker': {'color': '#ab63fa',
#                          'opacity': 0.8,
#                          'size': array([2032]),
#                          'sizemode': 'area',
#                          'sizeref': 5.925,
#                          'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'PHX',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([7.91340021]),
#               'xaxis': 'x',
#               'y': array([1]),
#               'yaxis': 'y'},
#              {'hovertemplate': ('<b>%{hovertext}</b><br><br>TEA' ... '=%{marker.size}<extra></extra>'),
#               'hovertext': array(['ANTHONY EDWARDS'], dtype=object),
#               'legendgroup': 'MIN',
#               'marker': {'color': '#FFA15A',
#                          'opacity': 0.8,
#                          'size': array([2049]),
#                          'sizemode': 'area',
#                          'sizeref': 5.925,
#                          'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'MIN',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([7.15613718]),
#               'xaxis': 'x',
#               'y': array([18]),
#               'yaxis': 'y'},
#              {'hovertemplate': ('<b>%{hovertext}</b><br><br>TEA' ... '=%{marker.size}<extra></extra>'),
#               'hovertext': array(['SHAI GILGEOUS-ALEXANDER'], dtype=object),
#               'legendgroup': 'OKC',
#               'marker': {'color': '#19d3f3',
#                          'opacity': 0.8,
#                          'size': array([2254]),
#                          'sizemode': 'area',
#                          'sizeref': 5.925,
#                          'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'OKC',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([16.99616138]),
#               'xaxis': 'x',
#               'y': array([640]),
#               'yaxis': 'y'},
#              {'hovertemplate': ('<b>%{hovertext}</b><br><br>TEA' ... '=%{marker.size}<extra></extra>'),
#               'hovertext': array(['NIKOLA JOKIĆ'], dtype=object),
#               'legendgroup': 'DEN',
#               'marker': {'color': '#FF6692',
#                          'opacity': 0.8,
#                          'size': array([2085]),
#                          'sizemode': 'area',
#                          'sizeref': 5.925,
#                          'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'DEN',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([21.9378882]),
#               'xaxis': 'x',
#               'y': array([926]),
#               'yaxis': 'y'},
#              {'hovertemplate': ('<b>%{hovertext}</b><br><br>TEA' ... '=%{marker.size}<extra></extra>'),
#               'hovertext': array(['DOMANTAS SABONIS'], dtype=object),
#               'legendgroup': 'SAC',
#               'marker': {'color': '#B6E880',
#                          'opacity': 0.8,
#                          'size': array([1593]),
#                          'sizemode': 'area',
#                          'sizeref': 5.925,
#                          'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'SAC',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([13.40040984]),
#               'xaxis': 'x',
#               'y': array([3]),
#               'yaxis': 'y'},
#              {'hovertemplate': ('<b>%{hovertext}</b><br><br>TEA' ... '=%{marker.size}<extra></extra>'),
#               'hovertext': array(['JAYSON TATUM'], dtype=object),
#               'legendgroup': 'BOS',
#               'marker': {'color': '#FF97FF',
#                          'opacity': 0.8,
#                          'size': array([1987]),
#                          'sizemode': 'area',
#                          'sizeref': 5.925,
#                          'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'BOS',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([10.8679017]),
#               'xaxis': 'x',
#               'y': array([86]),
#               'yaxis': 'y'}],
#     'layout': {'legend': {'itemsizing': 'constant', 'title': {'text': 'TEAM_ABBREVIATION_player'}, 'tracegroupgap': 0},
#                'template': '...',
#                'title': {'text': 'Impact of PER * Win Shares on MVP Points'},
#                'xaxis': {'anchor': 'y', 'domain': [0.0, 1.0], 'title': {'text': 'PER * Win Shares'}},
#                'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0], 'title': {'text': 'MVP Points Won'}}}
# })
# Figure({
#     'data': [{'hovertemplate': ('<b>%{hovertext}</b><br><br>TEA' ... '=%{marker.size}<extra></extra>'),
#               'hovertext': array(['GIANNIS ANTETOKOUNMPO'], dtype=object),
#               'legendgroup': 'MIL',
#               'marker': {'color': '#636efa',
#                          'opacity': 0.8,
#                          'size': array([1959]),
#                          'sizemode': 'area',
#                          'sizeref': 5.5625,
#                          'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'MIL',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([11.95671937]),
#               'xaxis': 'x',
#               'y': array([606]),
#               'yaxis': 'y'},
#              {'hovertemplate': ('<b>%{hovertext}</b><br><br>TEA' ... '=%{marker.size}<extra></extra>'),
#               'hovertext': array(['JALEN BRUNSON'], dtype=object),
#               'legendgroup': 'NYK',
#               'marker': {'color': '#EF553B',
#                          'opacity': 0.8,
#                          'size': array([1633]),
#                          'sizemode': 'area',
#                          'sizeref': 5.5625,
#                          'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'NYK',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([7.87351828]),
#               'xaxis': 'x',
#               'y': array([1]),
#               'yaxis': 'y'},
#              {'hovertemplate': ('<b>%{hovertext}</b><br><br>TEA' ... '=%{marker.size}<extra></extra>'),
#               'hovertext': array(['JIMMY BUTLER'], dtype=object),
#               'legendgroup': 'MIA',
#               'marker': {'color': '#00cc96',
#                          'opacity': 0.8,
#                          'size': array([1466]),
#                          'sizemode': 'area',
#                          'sizeref': 5.5625,
#                          'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'MIA',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([11.96632367]),
#               'xaxis': 'x',
#               'y': array([3]),
#               'yaxis': 'y'},
#              {'hovertemplate': ('<b>%{hovertext}</b><br><br>TEA' ... '=%{marker.size}<extra></extra>'),
#               'hovertext': array(['STEPHEN CURRY'], dtype=object),
#               'legendgroup': 'GSW',
#               'marker': {'color': '#ab63fa',
#                          'opacity': 0.8,
#                          'size': array([1648]),
#                          'sizemode': 'area',
#                          'sizeref': 5.5625,
#                          'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'GSW',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([8.68809892]),
#               'xaxis': 'x',
#               'y': array([5]),
#               'yaxis': 'y'},
#              {'hovertemplate': ('<b>%{hovertext}</b><br><br>TEA' ... '=%{marker.size}<extra></extra>'),
#               'hovertext': array(['LUKA DONČIĆ'], dtype=object),
#               'legendgroup': 'DAL',
#               'marker': {'color': '#FFA15A',
#                          'opacity': 0.8,
#                          'size': array([2138]),
#                          'sizemode': 'area',
#                          'sizeref': 5.5625,
#                          'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'DAL',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([12.79799247]),
#               'xaxis': 'x',
#               'y': array([10]),
#               'yaxis': 'y'},
#              {'hovertemplate': ('<b>%{hovertext}</b><br><br>TEA' ... '=%{marker.size}<extra></extra>'),
#               'hovertext': array(['JOEL EMBIID'], dtype=object),
#               'legendgroup': 'PHI',
#               'marker': {'color': '#19d3f3',
#                          'opacity': 0.8,
#                          'size': array([2183]),
#                          'sizemode': 'area',
#                          'sizeref': 5.5625,
#                          'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'PHI',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([15.62272329]),
#               'xaxis': 'x',
#               'y': array([915]),
#               'yaxis': 'y'},
#              {'hovertemplate': ('<b>%{hovertext}</b><br><br>TEA' ... '=%{marker.size}<extra></extra>'),
#               'hovertext': array(["DE'AARON FOX", 'DOMANTAS SABONIS'], dtype=object),
#               'legendgroup': 'SAC',
#               'marker': {'color': '#FF6692',
#                          'opacity': 0.8,
#                          'size': array([1826, 1510]),
#                          'sizemode': 'area',
#                          'sizeref': 5.5625,
#                          'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'SAC',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([ 7.28755647, 13.01447368]),
#               'xaxis': 'x',
#               'y': array([ 2, 27]),
#               'yaxis': 'y'},
#              {'hovertemplate': ('<b>%{hovertext}</b><br><br>TEA' ... '=%{marker.size}<extra></extra>'),
#               'hovertext': array(['SHAI GILGEOUS-ALEXANDER'], dtype=object),
#               'legendgroup': 'OKC',
#               'marker': {'color': '#B6E880',
#                          'opacity': 0.8,
#                          'size': array([2135]),
#                          'sizemode': 'area',
#                          'sizeref': 5.5625,
#                          'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'OKC',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([12.47110927]),
#               'xaxis': 'x',
#               'y': array([46]),
#               'yaxis': 'y'},
#              {'hovertemplate': ('<b>%{hovertext}</b><br><br>TEA' ... '=%{marker.size}<extra></extra>'),
#               'hovertext': array(['NIKOLA JOKIĆ'], dtype=object),
#               'legendgroup': 'DEN',
#               'marker': {'color': '#FF97FF',
#                          'opacity': 0.8,
#                          'size': array([1690]),
#                          'sizemode': 'area',
#                          'sizeref': 5.5625,
#                          'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'DEN',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([18.8446836]),
#               'xaxis': 'x',
#               'y': array([674]),
#               'yaxis': 'y'},
#              {'hovertemplate': ('<b>%{hovertext}</b><br><br>TEA' ... '=%{marker.size}<extra></extra>'),
#               'hovertext': array(['DONOVAN MITCHELL'], dtype=object),
#               'legendgroup': 'CLE',
#               'marker': {'color': '#FECB52',
#                          'opacity': 0.8,
#                          'size': array([1922]),
#                          'sizemode': 'area',
#                          'sizeref': 5.5625,
#                          'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'CLE',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([8.53404605]),
#               'xaxis': 'x',
#               'y': array([30]),
#               'yaxis': 'y'},
#              {'hovertemplate': ('<b>%{hovertext}</b><br><br>TEA' ... '=%{marker.size}<extra></extra>'),
#               'hovertext': array(['JA MORANT'], dtype=object),
#               'legendgroup': 'MEM',
#               'marker': {'color': '#636efa',
#                          'opacity': 0.8,
#                          'size': array([1596]),
#                          'sizemode': 'area',
#                          'sizeref': 5.5625,
#                          'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'MEM',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([6.89938398]),
#               'xaxis': 'x',
#               'y': array([1]),
#               'yaxis': 'y'},
#              {'hovertemplate': ('<b>%{hovertext}</b><br><br>TEA' ... '=%{marker.size}<extra></extra>'),
#               'hovertext': array(['JAYSON TATUM'], dtype=object),
#               'legendgroup': 'BOS',
#               'marker': {'color': '#EF553B',
#                          'opacity': 0.8,
#                          'size': array([2225]),
#                          'sizemode': 'area',
#                          'sizeref': 5.5625,
#                          'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'BOS',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([11.54154466]),
#               'xaxis': 'x',
#               'y': array([280]),
#               'yaxis': 'y'}],
#     'layout': {'legend': {'itemsizing': 'constant', 'title': {'text': 'TEAM_ABBREVIATION_player'}, 'tracegroupgap': 0},
#                'template': '...',
#                'title': {'text': 'Impact of PER * Win Shares on MVP Points'},
#                'xaxis': {'anchor': 'y', 'domain': [0.0, 1.0], 'title': {'text': 'PER * Win Shares'}},
#                'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0], 'title': {'text': 'MVP Points Won'}}}
# })
